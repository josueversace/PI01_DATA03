# %% [markdown]
# # Importando librerias necesarias

# %%
import numpy as np
import pandas as pd
import os
import mysql.connector
import sqlalchemy

# %% [markdown]
# ## Leyendo Circuits

# %%
circuits = pd.read_csv('Datasets/circuits.csv')

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %% [markdown]
# # observamos si hay datos faltantes

# %%
circuits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   77 non-null     int64
#  1   circuitRef  77 non-null     object
#  2   name        77 non-null     object
#  3   location    77 non-null     object
#  4   country     77 non-null     object
#  5   lat         77 non-null     float64
#  6   lng         77 non-null     float64
#  7   alt         77 non-null     int64
#  8   url         77 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 5.5+ KB

# %% [markdown]
# ---

# %% [markdown]
# ### Leyendo Races

# %%
races = pd.read_csv('Datasets/races.csv')
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %% [markdown]
# #### Observamos si hay datos faltantes

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   raceId     1058 non-null   int64
#  1   year       1058 non-null   int64
#  2   round      1058 non-null   int64
#  3   circuitId  1058 non-null   int64
#  4   name       1058 non-null   object
#  5   date       1058 non-null   object
#  6   time       1058 non-null   object
#  7   url        1058 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 66.2+ KB

# %% [markdown]
# ---

# %% [markdown]
# ### Leyendo results `(json)`

# %%
resultados = 'Datasets/results.json'
result = pd.read_json(resultados, lines=True)
result.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452           218.3         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
result.tail()
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 24955     24961    1047       841             51     99    14       16
# 24956     24962    1047       849              3      6    18       17
# 24957     24963    1047       825            210     20    20       18
# 24958     24964    1047       850            210     51    17       19
# 24959     24965    1047       815            211     11    19       \N
#
#       positionText  positionOrder  points  laps time milliseconds fastestLap  \
# 24955           16             16     0.0    54   \N           \N         29
# 24956           17             17     0.0    54   \N           \N         49
# 24957           18             18     0.0    54   \N           \N         50
# 24958           19             19     0.0    53   \N           \N         50
# 24959            R             20     0.0     8   \N           \N          6
#
#       rank fastestLapTime fastestLapSpeed  statusId
# 24955    7       1:41.675          196.65        11
# 24956   16       1:42.497         195.073        11
# 24957   13       1:41.999         196.025        11
# 24958    8       1:41.707         196.588        12
# 24959   19       1:43.263         193.625         7

# %% [markdown]
# #### Observamos datos faltantes

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24960 entries, 0 to 24959
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         24960 non-null  int64
#  1   raceId           24960 non-null  int64
#  2   driverId         24960 non-null  int64
#  3   constructorId    24960 non-null  int64
#  4   number           24960 non-null  object
#  5   grid             24960 non-null  int64
#  6   position         24960 non-null  object
#  7   positionText     24960 non-null  object
#  8   positionOrder    24960 non-null  int64
#  9   points           24960 non-null  float64
#  10  laps             24960 non-null  int64
#  11  time             24960 non-null  object
#  12  milliseconds     24960 non-null  object
#  13  fastestLap       24960 non-null  object
#  14  rank             24960 non-null  object
#  15  fastestLapTime   24960 non-null  object
#  16  fastestLapSpeed  24960 non-null  object
#  17  statusId         24960 non-null  int64
# dtypes: float64(1), int64(8), object(9)
# memory usage: 3.4+ MB

# %% [markdown]
# ---

# %% [markdown]
# ## Leyendo Constructors `json`

# %%
constructores = 'Datasets/constructors.json'
const = pd.read_json(constructores, lines=True)
const.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %% [markdown]
# ### Observamos datos faltantes

# %%
const.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   constructorId   211 non-null    int64
#  1   constructorRef  211 non-null    object
#  2   name            211 non-null    object
#  3   nationality     211 non-null    object
#  4   url             211 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 8.4+ KB

# %% [markdown]
# * * *

# %% [markdown]
# ## Leyendo qualifying `json`

# %%
qualify1 = 'Datasets/Qualifying/qualifying_split_1.json'
qualify01 = pd.read_json(qualify1)
qualify01.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
qualify2 = 'Datasets/Qualifying/qualifying_split_2.json'
qualify02 = pd.read_json(qualify2)
qualify02.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0       5002     861       811              3      19        13  1:38.437
# 1       5003     861       814             10      11        14  1:38.325
# 2       5004     861       817              5      16        15  1:38.419
# 3       5005     861       807             10      12        16  1:38.303
# 4       5006     861       155             15      14        17  1:38.372
#
#          q2  q3
# 0  1:37.841  \N
# 1  1:37.877  \N
# 2  1:37.883  \N
# 3  1:37.890  \N
# 4  1:38.069  \N

# %% [markdown]
# #### Concatenando qualifyers

# %%
qualify_concat = pd.concat([qualify01, qualify02],axis=0)
qualify_concat.tail()
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 3690       8730    1047         8             51       7        16  1:37.555
# 3691       8731    1047       825            210      20        17  1:37.863
# 3692       8732    1047       847              3      63        18  1:38.045
# 3693       8733    1047       850            210      51        19  1:38.173
# 3694       8734    1047       849              3       6        20  1:38.443
#
#       q2  q3
# 3690  \N  \N
# 3691  \N  \N
# 3692  \N  \N
# 3693  \N  \N
# 3694  \N  \N

# %% [markdown]
# ### Reseteando index

# %%
qualify_concat2 = qualify_concat.reset_index(drop=True)
qualify_concat2.tail()
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 8689       8730    1047         8             51       7        16  1:37.555
# 8690       8731    1047       825            210      20        17  1:37.863
# 8691       8732    1047       847              3      63        18  1:38.045
# 8692       8733    1047       850            210      51        19  1:38.173
# 8693       8734    1047       849              3       6        20  1:38.443
#
#       q2  q3
# 8689  \N  \N
# 8690  \N  \N
# 8691  \N  \N
# 8692  \N  \N
# 8693  \N  \N

# %%
qualify_concat2.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
qualify_concat.tail()
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 3690       8730    1047         8             51       7        16  1:37.555
# 3691       8731    1047       825            210      20        17  1:37.863
# 3692       8732    1047       847              3      63        18  1:38.045
# 3693       8733    1047       850            210      51        19  1:38.173
# 3694       8734    1047       849              3       6        20  1:38.443
#
#       q2  q3
# 3690  \N  \N
# 3691  \N  \N
# 3692  \N  \N
# 3693  \N  \N
# 3694  \N  \N

# %% [markdown]
# #### Revisando datos faltantes

# %%
qualify02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3695 entries, 0 to 3694
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   qualifyId      3695 non-null   int64
#  1   raceId         3695 non-null   int64
#  2   driverId       3695 non-null   int64
#  3   constructorId  3695 non-null   int64
#  4   number         3695 non-null   int64
#  5   position       3695 non-null   int64
#  6   q1             3695 non-null   object
#  7   q2             3695 non-null   object
#  8   q3             3695 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 259.9+ KB

# %% [markdown]
# ---

# %% [markdown]
# ## Leyendo Pi stops `json`

# %%
pit_stops_path = 'Datasets/pit_stops.json'
pit_stop = pd.read_json(pit_stops_path)
pit_stop
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 0        841       153     1    1  17:05:23   26.898         26898
# 1        841        30     1    1  17:05:52   25.021         25021
# 2        841        17     1   11  17:20:48   23.426         23426
# 3        841         4     1   12  17:22:34   23.251         23251
# 4        841        13     1   13  17:24:10   23.842         23842
# ...      ...       ...   ...  ...       ...      ...           ...
# 8025    1047        20     1   35  18:17:15    22.04         22040
# 8026    1047       849     2   35  18:17:41   22.384         22384
# 8027    1047       817     1   39  18:23:37   22.123         22123
# 8028    1047       825     2   47  18:39:11   23.098         23098
# 8029    1047       850     3   48  18:41:11   23.217         23217
#
# [8030 rows x 7 columns]

# %% [markdown]
# #### Datos faltantes

# %%
pit_stop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8030 entries, 0 to 8029
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   raceId        8030 non-null   int64
#  1   driverId      8030 non-null   int64
#  2   stop          8030 non-null   int64
#  3   lap           8030 non-null   int64
#  4   time          8030 non-null   object
#  5   duration      8030 non-null   object
#  6   milliseconds  8030 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 439.3+ KB

# %% [markdown]
# ---

# %% [markdown]
# ## Leyendo Laptimes

# %% [markdown]
# #### Leemos de uno por uno y luego concatenamos con pd.concat

# %%
union_lap1 = 'Datasets/lap_times/lap_times_split_1.csv'
union_lap01 = pd.read_csv(union_lap1, header=None)

union_lap2= 'Datasets/lap_times/lap_times_split_2.csv'
union_lap02 = pd.read_csv(union_lap2, header=None)

union_lap3 = 'Datasets/lap_times/lap_times_split_3.csv'
union_lap03 = pd.read_csv(union_lap3, header=None)

union_lap4 = 'Datasets/lap_times/lap_times_split_4.csv'
union_lap04 = pd.read_csv(union_lap4, header=None)

union_lap5 = 'Datasets/lap_times/lap_times_split_5.csv'
union_lap05 = pd.read_csv(union_lap5, header=None)

lap_times_concat = pd.concat([union_lap01, union_lap02, union_lap03, union_lap04, union_lap05], axis=0)
lap_times_concat2 = lap_times_concat.reset_index(drop=True)

lap_times_concat2
# Out:
#            0    1  2   3         4       5
# 0        841   20  1   1  1:38.109   98109
# 1        841   20  2   1  1:33.006   93006
# 2        841   20  3   1  1:32.713   92713
# 3        841   20  4   1  1:32.803   92803
# 4        841   20  5   1  1:32.342   92342
# ...      ...  ... ..  ..       ...     ...
# 490899  1047  815  4  17  1:44.762  104762
# 490900  1047  815  5  16  1:43.786  103786
# 490901  1047  815  6  15  1:43.263  103263
# 490902  1047  815  7  15  1:45.123  105123
# 490903  1047  815  8  14  1:44.231  104231
#
# [490904 rows x 6 columns]

# %% [markdown]
# #### Corroboramos la integridad y datos faltantes

# %%
lap_times_concat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490904 entries, 0 to 490903
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       490904 non-null  int64
#  1   1       490904 non-null  int64
#  2   2       490904 non-null  int64
#  3   3       490904 non-null  int64
#  4   4       490904 non-null  object
#  5   5       490904 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 22.5+ MB

# %% [markdown]
# #### Cambiando nombre de las columnas para poder manipularlas luego
# 4 = Tiempo
# 1 = Driver id

# %%
lap_times_concat2 = lap_times_concat2.rename(
    columns={lap_times_concat2.columns[4]: 'tiempo'})
lap_times_concat2 = lap_times_concat2.rename(
    columns={lap_times_concat2.columns[1]: 'Driver id'})
lap_times_concat2 = lap_times_concat2.rename(
    columns={lap_times_concat2.columns[0]: 'race id'})
    
lap_times_concat2
# Out:
#         race id  Driver id  2   3    tiempo       5
# 0           841         20  1   1  1:38.109   98109
# 1           841         20  2   1  1:33.006   93006
# 2           841         20  3   1  1:32.713   92713
# 3           841         20  4   1  1:32.803   92803
# 4           841         20  5   1  1:32.342   92342
# ...         ...        ... ..  ..       ...     ...
# 490899     1047        815  4  17  1:44.762  104762
# 490900     1047        815  5  16  1:43.786  103786
# 490901     1047        815  6  15  1:43.263  103263
# 490902     1047        815  7  15  1:45.123  105123
# 490903     1047        815  8  14  1:44.231  104231
#
# [490904 rows x 6 columns]

# %%
lap_times_concat2.columns
# Out:
# Index(['race id', 'Driver id', 2, 3, 'tiempo', 5], dtype='object')

# %%
lap_times_concat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490904 entries, 0 to 490903
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   race id    490904 non-null  int64
#  1   Driver id  490904 non-null  int64
#  2   2          490904 non-null  int64
#  3   3          490904 non-null  int64
#  4   tiempo     490904 non-null  object
#  5   5          490904 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 22.5+ MB

# %%
lap_times_concat2['tiempo'].min()
# Out:
# '0:55.404'

# %% [markdown]
# #### Ordenando por tiempo

# %%
by_time = lap_times_concat2.sort_values('tiempo')
by_time.head()
# Out:
#         race id  Driver id   2   3    tiempo      5
# 488409     1046        847  80  14  0:55.404  55404
# 488412     1046        847  83  12  0:56.319  56319
# 488404     1046        847  75   2  0:56.393  56393
# 488405     1046        847  76   2  0:56.442  56442
# 488413     1046        847  84  11  0:56.499  56499

# %%
by_time.tail()
# Out:
#         race id  Driver id   2   3    tiempo       5
# 227936      138         62  29  15  8:30.556  510556
# 440248     1001        817   2  17  8:44.604  524604
# 151841      197         35  23  13  9:06.038  546038
# 187749      167         23  10  18  9:24.047  564047
# 277689       83         13  43  16  9:45.712  585712

# %% [markdown]
# #### Reseteamos el index

# %%
lap_times_concat3 = by_time.reset_index(drop=True)
lap_times_concat3
# Out:
#         race id  Driver id   2   3    tiempo       5
# 0          1046        847  80  14  0:55.404   55404
# 1          1046        847  83  12  0:56.319   56319
# 2          1046        847  75   2  0:56.393   56393
# 3          1046        847  76   2  0:56.442   56442
# 4          1046        847  84  11  0:56.499   56499
# ...         ...        ...  ..  ..       ...     ...
# 490899      138         62  29  15  8:30.556  510556
# 490900     1001        817   2  17  8:44.604  524604
# 490901      197         35  23  13  9:06.038  546038
# 490902      167         23  10  18  9:24.047  564047
# 490903       83         13  43  16  9:45.712  585712
#
# [490904 rows x 6 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Leyendo drivers`json`

# %%
drivers00 = 'Datasets/drivers.json'
drivers = pd.read_json(drivers00,  lines=True)
drivers
# Out:
#      driverId          driverRef number code  \
# 0           1           hamilton     44  HAM
# 1           2           heidfeld     \N  HEI
# 2           3            rosberg      6  ROS
# 3           4             alonso     14  ALO
# 4           5         kovalainen     \N  KOV
# ..        ...                ...    ...  ...
# 848       850  pietro_fittipaldi     51  FIT
# 849       851             aitken     89  AIT
# 850       852            tsunoda     \N  TSU
# 851       853            mazepin     \N  MAZ
# 852       854    mick_schumacher     \N  SCH
#
#                                                 name         dob nationality  \
# 0       {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1        {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2         {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3      {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# 4    {'forename': 'Heikki', 'surname': 'Kovalainen'}  1981-10-19     Finnish
# ..                                               ...         ...         ...
# 848  {'forename': 'Pietro', 'surname': 'Fittipaldi'}  1996-06-25   Brazilian
# 849        {'forename': 'Jack', 'surname': 'Aitken'}  1995-09-23     British
# 850       {'forename': 'Yuki', 'surname': 'Tsunoda'}  2000-05-11    Japanese
# 851     {'forename': 'Nikita', 'surname': 'Mazepin'}  1999-03-02     Russian
# 852    {'forename': 'Mick', 'surname': 'Schumacher'}  1999-03-22      German
#
#                                                 url
# 0       http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1        http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2         http://en.wikipedia.org/wiki/Nico_Rosberg
# 3      http://en.wikipedia.org/wiki/Fernando_Alonso
# 4    http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ..                                              ...
# 848  http://en.wikipedia.org/wiki/Pietro_Fittipaldi
# 849        http://en.wikipedia.org/wiki/Jack_Aitken
# 850       http://en.wikipedia.org/wiki/Yuki_Tsunoda
# 851     http://en.wikipedia.org/wiki/Nikita_Mazepin
# 852    http://en.wikipedia.org/wiki/Mick_Schumacher
#
# [853 rows x 8 columns]

# %% [markdown]
# #### Datos faltantes

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     853 non-null    int64
#  1   driverRef    853 non-null    object
#  2   number       853 non-null    object
#  3   code         853 non-null    object
#  4   name         853 non-null    object
#  5   dob          853 non-null    object
#  6   nationality  853 non-null    object
#  7   url          853 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 53.4+ KB

# %% [markdown]
# Transformando columna 'Name' en "nombre y apellido'

# %%
name_surname = drivers['name'].apply(pd.Series)
name_surname
# Out:
#      forename     surname
# 0       Lewis    Hamilton
# 1        Nick    Heidfeld
# 2        Nico     Rosberg
# 3    Fernando      Alonso
# 4      Heikki  Kovalainen
# ..        ...         ...
# 848    Pietro  Fittipaldi
# 849      Jack      Aitken
# 850      Yuki     Tsunoda
# 851    Nikita     Mazepin
# 852      Mick  Schumacher
#
# [853 rows x 2 columns]

# %%
drivers['codes'] = drivers['code'].str[:3]

# %%
drivers_final = pd.concat([drivers,name_surname], axis=1).drop('name',axis=1)
drivers_final
# Out:
#      driverId          driverRef number code         dob nationality  \
# 0           1           hamilton     44  HAM  1985-01-07     British
# 1           2           heidfeld     \N  HEI  1977-05-10      German
# 2           3            rosberg      6  ROS  1985-06-27      German
# 3           4             alonso     14  ALO  1981-07-29     Spanish
# 4           5         kovalainen     \N  KOV  1981-10-19     Finnish
# ..        ...                ...    ...  ...         ...         ...
# 848       850  pietro_fittipaldi     51  FIT  1996-06-25   Brazilian
# 849       851             aitken     89  AIT  1995-09-23     British
# 850       852            tsunoda     \N  TSU  2000-05-11    Japanese
# 851       853            mazepin     \N  MAZ  1999-03-02     Russian
# 852       854    mick_schumacher     \N  SCH  1999-03-22      German
#
#                                                 url codes  forename  \
# 0       http://en.wikipedia.org/wiki/Lewis_Hamilton   HAM     Lewis
# 1        http://en.wikipedia.org/wiki/Nick_Heidfeld   HEI      Nick
# 2         http://en.wikipedia.org/wiki/Nico_Rosberg   ROS      Nico
# 3      http://en.wikipedia.org/wiki/Fernando_Alonso   ALO  Fernando
# 4    http://en.wikipedia.org/wiki/Heikki_Kovalainen   KOV    Heikki
# ..                                              ...   ...       ...
# 848  http://en.wikipedia.org/wiki/Pietro_Fittipaldi   FIT    Pietro
# 849        http://en.wikipedia.org/wiki/Jack_Aitken   AIT      Jack
# 850       http://en.wikipedia.org/wiki/Yuki_Tsunoda   TSU      Yuki
# 851     http://en.wikipedia.org/wiki/Nikita_Mazepin   MAZ    Nikita
# 852    http://en.wikipedia.org/wiki/Mick_Schumacher   SCH      Mick
#
#         surname
# 0      Hamilton
# 1      Heidfeld
# 2       Rosberg
# 3        Alonso
# 4    Kovalainen
# ..          ...
# 848  Fittipaldi
# 849      Aitken
# 850     Tsunoda
# 851     Mazepin
# 852  Schumacher
#
# [853 rows x 10 columns]

# %%
drivers_final.columns
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'dob', 'nationality', 'url',
#        'codes', 'forename', 'surname'],
#       dtype='object')

# %% [markdown]
# #### reindexamos columnas

# %%
drivers_final = drivers_final.reindex(
    columns=['driverId', 'forename', 'surname', 'nationality', 'driverRef', 'codes', 'number', 'dob', 'url'])
drivers_final
# Out:
#      driverId  forename     surname nationality          driverRef codes  \
# 0           1     Lewis    Hamilton     British           hamilton   HAM
# 1           2      Nick    Heidfeld      German           heidfeld   HEI
# 2           3      Nico     Rosberg      German            rosberg   ROS
# 3           4  Fernando      Alonso     Spanish             alonso   ALO
# 4           5    Heikki  Kovalainen     Finnish         kovalainen   KOV
# ..        ...       ...         ...         ...                ...   ...
# 848       850    Pietro  Fittipaldi   Brazilian  pietro_fittipaldi   FIT
# 849       851      Jack      Aitken     British             aitken   AIT
# 850       852      Yuki     Tsunoda    Japanese            tsunoda   TSU
# 851       853    Nikita     Mazepin     Russian            mazepin   MAZ
# 852       854      Mick  Schumacher      German    mick_schumacher   SCH
#
#     number         dob                                             url
# 0       44  1985-01-07     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1       \N  1977-05-10      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2        6  1985-06-27       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3       14  1981-07-29    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4       \N  1981-10-19  http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ..     ...         ...                                             ...
# 848     51  1996-06-25  http://en.wikipedia.org/wiki/Pietro_Fittipaldi
# 849     89  1995-09-23        http://en.wikipedia.org/wiki/Jack_Aitken
# 850     \N  2000-05-11       http://en.wikipedia.org/wiki/Yuki_Tsunoda
# 851     \N  1999-03-02     http://en.wikipedia.org/wiki/Nikita_Mazepin
# 852     \N  1999-03-22    http://en.wikipedia.org/wiki/Mick_Schumacher
#
# [853 rows x 9 columns]

# %% [markdown]
# #### Corroborar datos faltantes

# %%
drivers_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     853 non-null    int64
#  1   forename     853 non-null    object
#  2   surname      853 non-null    object
#  3   nationality  853 non-null    object
#  4   driverRef    853 non-null    object
#  5   codes        853 non-null    object
#  6   number       853 non-null    object
#  7   dob          853 non-null    object
#  8   url          853 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 60.1+ KB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Una vez tenemos todos las tablas solo para elaborar consultas segun la consigna, Exportamos los datasets a una base de datos

# %% [markdown]
# ## Usamos la libreria de sql alchemy

# %%
# Nos conectamos a la base de datos
database_username = 'root'
database_password = '70040691'
database_ip = '127.0.0.1'
database_name = 'PI'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password,
                                                      database_ip, database_name), pool_recycle=1, pool_timeout=57600).connect()
#Exportamos las tablas

# df Drivers
drivers_final.to_sql(con=database_connection, name='drivers',
            if_exists='replace', chunksize=100)
print('DF drivers cargado!')
print('1/9 COMPLETE!')

# df circuits
circuits.to_sql(con=database_connection, name='circuits',
                     if_exists='replace', chunksize=100)
print('DF circuits cargado!')
print('2/9 COMPLETE!')

# df races
races.to_sql(con=database_connection, name='races',
                     if_exists='replace', chunksize=100)
print('DF races cargado!')
print('3/9 COMPLETE!')

#result
result.to_sql(con=database_connection, name='results',
                     if_exists='replace', chunksize=100)
print('DF results cargado!')
print('4/9 COMPLETE!')

#constructores
const.to_sql(con=database_connection, name='constructors',
                     if_exists='replace', chunksize=100)
print('DF constructors cargado!')
print('5/9 COMPLETE!')


# qualifyings
qualify02.to_sql(con=database_connection, name='qualifying',
                     if_exists='replace', chunksize=100)
print('DF qualifying cargado!')
print('6/9 COMPLETE!')

# Pit stop
pit_stop.to_sql(con=database_connection, name='pit_stops',
                     if_exists='replace', chunksize=100)
print('DF pit_stops cargado!')
print('7/9 COMPLETE!')

# lap_times
lap_times_concat3.to_sql(con=database_connection, name='lap_times',
                     if_exists='replace', chunksize=100)
print('DF lap_times cargado!')
print('8/9 COMPLETE!')

#
result.to_sql(con=database_connection, name='results',
                     if_exists='replace', chunksize=100)
print('DF result cargado!')
print('9/9 COMPLETE!')

# Cerramos la sesion de nuestra base de datos
database_connection.close()
# Out:
# DF drivers cargado!
# 1/9 COMPLETE!
# DF circuits cargado!
# 2/9 COMPLETE!
# DF races cargado!
# 3/9 COMPLETE!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/JVersace/Documents/PI/PI01_DATA03/main.ipynb Celda 51 in <cell line: 28>()
#      <a href='vscode-notebook-cell:/Users/JVersace/Documents/PI/PI01_DATA03/main.ipynb#Y102sZmlsZQ%3D%3D?line=24'>25</a> print('3/9 COMPLETE!')
#      <a href='vscode-notebook-cell:/Users/JVersace/Documents/PI/PI01_DATA03/main.ipynb#Y102sZmlsZQ%3D%3D?line=26'>27</a> #result
# ---> <a href='vscode-notebook-cell:/Users/JVersace/Documents/PI/PI01_DATA03/main.ipynb#Y102sZmlsZQ%3D%3D?line=27'>28</a> result.to_sql(con=database_connection, name='results',
#      <a href='vscode-notebook-cell:/Users/JVersace/Documents/PI/PI01_DATA03/main.ipynb#Y102sZmlsZQ%3D%3D?line=28'>29</a>                      if_exists='replace', chunksize=100)
#      <a href='vscode-notebook-cell:/Users/JVersace/Documents/PI/PI01_DATA03/main.ipynb#Y102sZmlsZQ%3D%3D?line=29'>30</a> print('DF results cargado!')
#      <a href='vscode-notebook-cell:/Users/JVersace/Documents/PI/PI01_DATA03/main.ipynb#Y102sZmlsZQ%3D%3D?line=30'>31</a> print('4/9 COMPLETE!')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:2963, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2806 """
#    2807 Write records stored in a DataFrame to a SQL database.
#    2808
#    (...)
#    2959 [(1,), (None,), (2,)]
#    2960 """  # noqa:E501
#    2961 from pandas.io import sql
# -> 2963 return sql.to_sql(
#    2964     self,
#    2965     name,
#    2966     con,
#    2967     schema=schema,
#    2968     if_exists=if_exists,
#    2969     index=index,
#    2970     index_label=index_label,
#    2971     chunksize=chunksize,
#    2972     dtype=dtype,
#    2973     method=method,
#    2974 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/sql.py:1739, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1727 sql_engine = get_engine(engine)
#    1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    (...)
#    1736     dtype=dtype,
#    1737 )
# -> 1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    1742     frame=frame,
#    1743     name=name,
#    1744     index=index,
#    1745     schema=schema,
#    1746     chunksize=chunksize,
#    1747     method=method,
#    1748     **engine_kwargs,
#    1749 )
#    1751 self.check_case_sensitive(name=name, schema=schema)
#    1752 return total_inserted
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/sql.py:1322, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1319 from sqlalchemy import exc
#    1321 try:
# -> 1322     return table.insert(chunksize=chunksize, method=method)
#    1323 except exc.SQLAlchemyError as err:
#    1324     # GH34431
#    1325     # https://stackoverflow.com/a/67358288/6067848
#    1326     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1327     )|inf can not be used with MySQL"""
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/sql.py:950, in SQLTable.insert(self, chunksize, method)
#     947     break
#     949 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 950 num_inserted = exec_insert(conn, keys, chunk_iter)
#     951 if num_inserted is None:
#     952     total_inserted = None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/sql.py:857, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     845 """
#     846 Execute SQL statement inserting data
#     847
#    (...)
#     854    Each item contains a list of values to be inserted
#     855 """
#     856 data = [dict(zip(keys, row)) for row in data_iter]
# --> 857 result = conn.execute(self.table.insert(), data)
#     858 return result.rowcount
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1380, in Connection.execute(self, statement, *multiparams, **params)
#    1376     util.raise_(
#    1377         exc.ObjectNotExecutableError(statement), replace_context=err
#    1378     )
#    1379 else:
# -> 1380     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:333, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     329 def _execute_on_connection(
#     330     self, connection, multiparams, params, execution_options, _force=False
#     331 ):
#     332     if _force or self.supports_execution:
# --> 333         return connection._execute_clauseelement(
#     334             self, multiparams, params, execution_options
#     335         )
#     336     else:
#     337         raise exc.ObjectNotExecutableError(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1572, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1560 compiled_cache = execution_options.get(
#    1561     "compiled_cache", self.engine._compiled_cache
#    1562 )
#    1564 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1565     dialect=dialect,
#    1566     compiled_cache=compiled_cache,
#    (...)
#    1570     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1571 )
# -> 1572 ret = self._execute_context(
#    1573     dialect,
#    1574     dialect.execution_ctx_cls._init_compiled,
#    1575     compiled_sql,
#    1576     distilled_params,
#    1577     execution_options,
#    1578     compiled_sql,
#    1579     distilled_params,
#    1580     elem,
#    1581     extracted_params,
#    1582     cache_hit=cache_hit,
#    1583 )
#    1584 if has_events:
#    1585     self.dispatch.after_execute(
#    1586         self,
#    1587         elem,
#    (...)
#    1591         ret,
#    1592     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2128, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2124         util.raise_(
#    2125             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126         )
#    2127     else:
# -> 2128         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2130 finally:
#    2131     del self._reentrant_error
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1880, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1878                 break
#    1879     if not evt_handled:
# -> 1880         self.dialect.do_executemany(
#    1881             cursor, statement, parameters, context
#    1882         )
#    1883 elif not parameters and context.no_parameters:
#    1884     if self.dialect._has_events:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sqlalchemy/engine/default.py:733, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     732 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 733     cursor.executemany(statement, parameters)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mysql/connector/cursor_cext.py:375, in CMySQLCursor.executemany(self, operation, seq_params)
#     373 try:
#     374     for params in seq_params:
# --> 375         self.execute(operation, params)
#     376         try:
#     377             while True:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mysql/connector/cursor_cext.py:276, in CMySQLCursor.execute(self, operation, params, multi)
#     271             raise ProgrammingError(
#     272                 "Not all parameters were used in the SQL statement"
#     273             )
#     275 try:
# --> 276     result = self._cnx.cmd_query(
#     277         stmt,
#     278         raw=self._raw,
#     279         buffered=self._buffered,
#     280         raw_as_string=self._raw_as_string,
#     281     )
#     282 except MySQLInterfaceError as err:
#     283     raise get_mysql_exception(
#     284         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     285     ) from err
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mysql/connector/connection_cext.py:547, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     544         raise InternalError("Unread result found")
#     545     statement_id.stmt_reset()
# --> 547 def cmd_query(self, query, raw=None, buffered=False, raw_as_string=False):
#     548     """Send a query to the MySQL server"""
#     549     self.handle_unread_result()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Todas las consultas las realizaremos en MySql

# %% [markdown]
# Las consultas hechas estan en Consultas.sql. Quedan asi:

# %%
dict1 = {"año": "2021", "total carreras": "23"}
dict2 = {"Nombre": "Fernando Alonso", "total veces": "57"}
dict3 = {"Circuito": "Italian Grand Prix71", "Cantidad": "71"}
dict4 = {"Nombre": "Lewis Hamilton", "total puntos": "913"}
# Out:
#       year
# year
# 2021    23
